# %%
import requests

url = "https://covid-193.p.rapidapi.com/statistics"

headers = {
	"x-rapidapi-key": "84fe14bf83msh0bf8f81ffe0b0d3p1a8fcejsna6d8fb35c16b",
	"x-rapidapi-host": "covid-193.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'get': 'statistics', 'parameters': [], 'errors': [], 'results': 238, 'response': [{'continent': 'Asia', 'country': 'China', 'population': 1448471400, 'cases': {'new': None, 'active': 118977, 'critical': None, 'recovered': 379053, '1M_pop': '347', 'total': 503302}, 'deaths': {'new': None, '1M_pop': '4', 'total': 5272}, 'tests': {'1M_pop': '110461', 'total': 160000000}, 'day': '2024-10-23', 'time': '2024-10-23T18:45:26+00:00'}, {'continent': 'Africa', 'country': 'Saint-Helena', 'population': 6115, 'cases': {'new': None, 'active': 2164, 'critical': None, 'recovered': 2, '1M_pop': '354211', 'total': 2166}, 'deaths': {'new': None, '1M_pop': None, 'total': None}, 'tests': {'1M_pop': None, 'total': None}, 'day': '2024-10-23', 'time': '2024-10-23T18:45:25+00:00'}, {'continent': 'South-America', 'country': 'Falkland-Islands', 'population': 3539, 'cases': {'new': None, 'active': 0, 'critical': None, 'recovered': 1930, '1M_pop': '545352', 'total': 1930}, 'deaths': {'new': None, '1M_pop': None,
# ...

# %%
import pandas as pd

# %%
response = requests.get("https://jsonformatter.org/json-viewer")  # Hit this url on the json viewer bebsite
# Out:
# <Response [200]>

# %%
df = pd.DataFrame(response.json()['response'])
df
# Out:
#          continent           country    population  \
# 0             Asia             China  1.448471e+09
# 1           Africa      Saint-Helena  6.115000e+03
# 2    South-America  Falkland-Islands  3.539000e+03
# 3    North-America        Montserrat  4.965000e+03
# 4             None  Diamond-Princess           NaN
# ..             ...               ...           ...
# 233         Europe           Germany  8.388360e+07
# 234  South-America            Brazil  2.153536e+08
# 235           Asia           S-Korea  5.132990e+07
# 236           Asia             Japan  1.255848e+08
# 237  North-America     North-America           NaN
#
#                                                  cases  \
# 0    {'new': None, 'active': 118977, 'critical': No...
# 1    {'new': None, 'active': 2164, 'critical': None...
# 2    {'new': None, 'active': 0, 'critical': None, '...
# 3    {'new': None, 'active': 19, 'critical': None, ...
# 4    {'new': None, 'active': 0, 'critical': None, '...
# ...

# %%
df.shape
# Out:
# (238, 8)

# %%
df.to_csv("covid_19.csv",index=False)
